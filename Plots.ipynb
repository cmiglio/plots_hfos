# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import functools
sns.set(style="darkgrid")
# %matplotlib inline

# %%
def isState(state):
    a='nose'
    if state == 1:
        a='interictal'
    elif state ==2:
        a='ictal'
    elif state==3:
        a='sleep'
    return a

def conjunction(*conditions):
    return functools.reduce(np.logical_and, conditions)

# %%
a=isState(1)


results=pd.read_csv('resultados.csv')

# Preprocesado
results['nState']=results['State'].apply(lambda x: isState(x))

results['cond1']=results['trough']/results['HIFP']
results['cond2']=results['HIFP']/results['LOFP']
results['cond3']=results['trough_high']/results['HIFP']
results['ratioHL']=results['mHPow']/results['mLPow']

#ishfo=(results.cond1<0.25 & results.cond2>1 & results.cond3<0.25)

# %%
a=results.cond1<0.25  
b=results.cond2>1
c=results.cond3<0.25

## Para añadir la condicion 3:
#hfos=results[conjunction(a,b,c)]
## Sin condicion 3:
hfos = results[conjunction(a,b)]

# %%
hfos
# Out:
#         State  Channel Electrode   Labels       HIFP       LOFP        fHFO  \
# 1           1        1        TA  TA.d4-3   2.607546   2.485715   85.883871
# 5           1        1        TA  TA.d4-3   2.573809   2.165837   92.034059
# 7           1        1        TA  TA.d4-3   2.275674   1.800173   99.784295
# 8           1        1        TA  TA.d4-3   1.815585   0.655052   82.580645
# 9           1        1        TA  TA.d4-3   2.525828   2.416221   86.042475
# 10          1        1        TA  TA.d4-3   2.382972   1.392670   92.837715
# 14          1        1        TA  TA.d4-3   2.381816   1.387986   82.302804
# 15          1        1        TA  TA.d4-3   2.563149   1.022830   91.000935
# 18          1        1        TA  TA.d4-3   1.855530   0.941773   97.061611
# 19          1        1        TA  TA.d4-3   2.262682   1.573713  113.019981
# 29          1        1        TA  TA.d4-3   2.648833   1.526011   89.540465
# ...

# %%
g = sns.FacetGrid(hfos, row="Electrode", col="nState", margin_titles=True)
bins = np.linspace(80, 200, 20)
g.map(plt.hist, "fHFO", color="steelblue", bins=bins, lw=0)
g.savefig('histogramas_frecuencia_con_c3.png')

# %%
g = sns.FacetGrid(hfos, row="Electrode", col="nState", margin_titles=True)
bins = np.linspace(0, 5, 20)
g.map(plt.hist, "ratioHL", color="steelblue", bins=bins, lw=0)
g.savefig('histogramas_ratioHL_con_c3.png')

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Electrode", y="fHFO", hue="nState", data=hfos, palette="vlag")
f.legend(loc=2)
fig.savefig('boxplot_frecuencia_con_c3.png')

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Electrode", y="ratioHL", hue="nState", data=hfos, palette="vlag")
f.legend(loc=2)
fig.savefig('boxplot_ratioHL_sin_c3.png')

# %%
a=hfos.groupby(by=['nState','Electrode']).count()['Channel']
a.unstack(0).plot.bar()

# %%
GA=hfos[hfos['Electrode']=='GA']

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="fHFO", hue="nState", data=GA, palette="vlag")
f.legend(loc=2)

# %%
H=hfos[hfos['Electrode']=='H']

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="fHFO", hue="nState", data=H, palette="vlag")
f.legend(loc=2)

# %%
IPO=hfos[hfos['Electrode']=='IPO']

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="fHFO", hue="nState", data=IPO, palette="vlag")
f.legend(loc=2)

# %%
OI=hfos[hfos['Electrode']=='OI']

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="fHFO", hue="nState", data=OI, palette="vlag")
f.legend(loc=2)

# %%
OS=hfos[hfos['Electrode']=='OS']

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="fHFO", hue="nState", data=OS, palette="vlag")
f.legend(loc=2)

# %%
PC=hfos[hfos['Electrode']=='PC']

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="fHFO", hue="nState", data=PC, palette="vlag")
f.legend(loc=2)

# %%
PCP=hfos[hfos['Electrode']=='PCP']

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="fHFO", hue="nState", data=PCP, palette="vlag")
f.legend(loc=2)

# %%
PP=hfos[hfos['Electrode']=='PP']

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="fHFO", hue="nState", data=PP, palette="vlag")
f.legend(loc=2)

# %%
TA=hfos[hfos['Electrode']=='TA']

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="fHFO", hue="nState", data=TA, palette="vlag")
f.legend(loc=2)

# %%
TB=hfos[hfos['Electrode']=='TB']

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="fHFO", hue="nState", data=TB, palette="vlag")
f.legend(loc=2)

# %%
TOB=hfos[hfos['Electrode']=='TOB']

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="fHFO", hue="nState", data=TOB, palette="vlag")
f.legend(loc=2)

# %%
TP=hfos[hfos['Electrode']=='TP']

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="fHFO", hue="nState", data=TP, palette="vlag")
f.legend(loc=2)

# %%
ICTAL=hfos[hfos['nState']=='ictal']
INTERICTAL=hfos[hfos['nState']=='interictal']
SLEEP=hfos[hfos['nState']=='sleep']

# %%
INTERICTAL.reset_index(drop = True, inplace = True) 
labels=INTERICTAL['Labels'].unique()
labels=np.asmatrix(labels)

chancount=np.matlib.zeros(np.shape(labels))
idx=np.arange(0,np.size(labels))
idx=np.asmatrix(idx)
for i, row in enumerate(INTERICTAL.Channel):
    chancount[0,row-1]=chancount[0,row-1]+1

chancount=chancount[0,0:79]  
idx=idx[0,0:79]
deciles=np.percentile(chancount, np.arange(0, 100, 25))

top10=chancount>=deciles[-1]

top10idx=idx[top10]+1

lista=[]
for i in np.nditer(top10idx):
    lista.append(i)

# %%
hfosTopDecile=hfos[hfos['Channel'].isin(lista)]

# %%
a4_dims = (15, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="fHFO", hue="nState", data=hfosTopDecile, palette="vlag")
f.legend(loc=2)
fig.savefig('boxplot_fHFO_sin_c3_top_cuartil.png')

# %%
a4_dims = (15, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="ratioHL", hue="nState", data=hfosTopDecile, palette="vlag")
f.legend(loc=2)
fig.savefig('boxplot_ratioHL_sin_c3_top_cuartil.png')

# %%
a4_dims = (15, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="cond2", hue="nState", data=hfosTopDecile, palette="vlag")
f.legend(loc=2)
fig.savefig('boxplot_cond2_sin_c3_top_cuartil.png')

# %%
a4_dims = (15, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="eSPE", hue="nState", data=hfosTopDecile, palette="vlag")
f.legend(loc=2)
fig.savefig('boxplot_eSPE_sin_c3_top_cuartil.png')

# %%
a4_dims = (15, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="sENT", hue="nState", data=hfosTopDecile, palette="vlag")
f.legend(loc=2)
fig.savefig('boxplot_sENT_sin_c3_top_cuartil.png')

# %%
a4_dims = (15, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
f=sns.boxplot(ax=ax,x="Labels", y="dur", hue="nState", data=hfosTopDecile, palette="vlag")
f.legend(loc=2)
